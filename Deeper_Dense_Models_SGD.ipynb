# %% [markdown]
# ## Deeper Dense Models (SGD optimizer)

# %%
import pandas as pd
import numpy as np

# %%
# %run load_mnist_dataset_flat.py

# %%
## Script create_dense_model.py
import tensorflow as tf
import numpy as np
from tensorflow import keras
DIGIT_CLASSES = 10
RESHAPED = 28 * 28 ## 784 pixels per image
import time
from datetime import datetime


def create_dense_model(hidden_layers=1, hidden_units_per_layer=128):
    """
    create a keras sequential model with the specified
    number of hidden_layers and number of units per layer
    """
    DIGIT_CLASSES = 10
    RESHAPED = 28 * 28 ## 784 pixels per image
    model = tf.keras.models.Sequential()
    count = 0
    
    
    count += 1
    model.add(keras.layers.Dense(units=hidden_units_per_layer,
        input_shape=(RESHAPED,),
        name=f'dense_layer_{count}', activation='relu'))
    
    for i in range(1, hidden_layers):
        count += 1
        model.add(keras.layers.Dense(units=hidden_units_per_layer,
           name=f'dense_layer_{count}', activation='relu'))
        
    count += 1        
    model.add(keras.layers.Dense(DIGIT_CLASSES,
       name=f'dense_layer_{count}', activation='softmax'))

    # summary of the model
    model.summary()
    return model


def run_dense_model(hidden_layers=1, hidden_units_per_layer=128, optimizer='SGD', verbose=1):
    """
    Create and run a dense Keras sequential model over the MNIST training data,
    using the specified numbers of hidden_layers, hidden_units_per_layer, and optimizer.
    Maybe add optional dropout TBD,
    Return values:
    history, training_time, test_accuracy, model
    """
    from keras.callbacks import EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss',verbose=1,patience=3,min_delta=0.0001)
    
    BATCH_SIZE = 128
    EPOCHS = 400
    VALIDATION_SPLIT = 0.2
    
    ## Load the training and test data
    X_train, X_test, Y_train, Y_test = load_mnist_dataset_flat()
    
    model = create_dense_model(hidden_layers, hidden_units_per_layer)
    
    start_time = time.time()

    # compiling the model
    model.compile(optimizer=optimizer, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    #training the model
    history = model.fit(X_train, Y_train,
                        batch_size=BATCH_SIZE, epochs=EPOCHS,
                        verbose=verbose, validation_split=VALIDATION_SPLIT,
                        callbacks=[early_stopping]
                       )
    
    elapsed_time = time.time() - start_time
    
    test_loss, test_accuracy = model.evaluate(X_test, Y_test)
    print(f'{hidden_layers=} {hidden_units_per_layer=} {optimizer=}')
    print(f'training elapsed_time = {elapsed_time:10.1f}')
    print('Test accuracy:', test_accuracy)
    
    return history, elapsed_time, test_accuracy, model

# %%
model = create_dense_model(hidden_layers=1, hidden_units_per_layer=64)
model.summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x000002225DD357C0>>

# %%
dense1 = pd.read_csv('data/dense_network_comparisons.csv')
display(dense1)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0    256.643188         0.9716
# 1             1.0                   128.0    269.815770         0.9742
# 2             1.0                   192.0    265.792969         0.9763
# 3             2.0                    64.0    134.144796         0.9690
# 4             2.0                   128.0    148.220814         0.9734
# 5             2.0                   192.0    147.220577         0.9746
# 6             3.0                    64.0     94.210800         0.9673
# 7             3.0                   128.0    106.395729         0.9729
# 8             3.0                   192.0     87.828249         0.9749
# 9             4.0                    64.0     69.781558         0.9695
# 10            4.0                   128.0     90.105224         0.9722
# 11            4.0                   192.0     99.254324         0.9722

# %%
dense2 = pd.read_csv('data/dense_network_comparisons2.csv')
display(dense2)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0     21.059321         0.9735
# 1             1.0                   128.0     19.197610         0.9765
# 2             1.0                   192.0     17.795359         0.9792
# 3             2.0                    64.0     15.609005         0.9716
# 4             2.0                   128.0     13.113215         0.9759
# 5             2.0                   192.0     13.247705         0.9776
# 6             3.0                    64.0     15.438182         0.9726
# 7             3.0                   128.0     13.106203         0.9698
# 8             3.0                   192.0     14.660831         0.9793
# 9             4.0                    64.0     20.492837         0.9721
# 10            4.0                   128.0     15.320420         0.9721
# 11            4.0                   192.0     12.650368         0.9774

# %%
dropout1 = pd.read_csv('data/dense_network_comparisons.csv')
display(dropout1)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0    256.643188         0.9716
# 1             1.0                   128.0    269.815770         0.9742
# 2             1.0                   192.0    265.792969         0.9763
# 3             2.0                    64.0    134.144796         0.9690
# 4             2.0                   128.0    148.220814         0.9734
# 5             2.0                   192.0    147.220577         0.9746
# 6             3.0                    64.0     94.210800         0.9673
# 7             3.0                   128.0    106.395729         0.9729
# 8             3.0                   192.0     87.828249         0.9749
# 9             4.0                    64.0     69.781558         0.9695
# 10            4.0                   128.0     90.105224         0.9722
# 11            4.0                   192.0     99.254324         0.9722

# %%
dropout2 = pd.read_csv('data/dense_network_comparisons2.csv')
display(dropout2)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0     21.059321         0.9735
# 1             1.0                   128.0     19.197610         0.9765
# 2             1.0                   192.0     17.795359         0.9792
# 3             2.0                    64.0     15.609005         0.9716
# 4             2.0                   128.0     13.113215         0.9759
# 5             2.0                   192.0     13.247705         0.9776
# 6             3.0                    64.0     15.438182         0.9726
# 7             3.0                   128.0     13.106203         0.9698
# 8             3.0                   192.0     14.660831         0.9793
# 9             4.0                    64.0     20.492837         0.9721
# 10            4.0                   128.0     15.320420         0.9721
# 11            4.0                   192.0     12.650368         0.9774

# %%
LABEL = 'SGD'
OPTIMIZER = 'SGD'
units = [64,128,192]
hidden_layers = [1,2,3,4]

test_data2 = []

for layers in hidden_layers:
    for hidden_units in units:
        history, elapsed_time, test_accuracy, model = \
        run_dense_model(hidden_layers=layers, hidden_units_per_layer=hidden_units, verbose=0, optimizer=OPTIMIZER)
        
        data2 = (layers, hidden_units, elapsed_time, test_accuracy)
        
        test_data2.append(data2)
        
        
df = pd.DataFrame(test_data2)
df.columns = ['hidden_layers', 'hidden_units_per_layer', 'elapsed_time', 'test_accuracy']
display(df)
path = f'data/DENSE_{LABEL}'
now = datetime.now()
result_name = now.strftime(f"{path}_%Y-%m-%d_%H_%M.csv")
print(f'Saving results to file {result_name}')
df.to_csv(result_name, index=False)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 177: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1034 - accuracy: 0.9695
# hidden_layers=1 hidden_units_per_layer=64 optimizer='SGD'
# training elapsed_time =      226.9
# Test accuracy: 0.9695000052452087
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 208: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0870 - accuracy: 0.9740
# hidden_layers=1 hidden_units_per_layer=128 optimizer='SGD'
# training elapsed_time =      284.9
# Test accuracy: 0.9739999771118164
# 60000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 152,650
# Trainable params: 152,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 222: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0792 - accuracy: 0.9762
# hidden_layers=1 hidden_units_per_layer=192 optimizer='SGD'
# training elapsed_time =      311.8
# Test accuracy: 0.9761999845504761
# 60000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dense_layer_3 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 116: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0934 - accuracy: 0.9706
# hidden_layers=2 hidden_units_per_layer=64 optimizer='SGD'
# training elapsed_time =      169.5
# Test accuracy: 0.9706000089645386
# 60000 train samples
# 10000 test samples
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 120: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0852 - accuracy: 0.9740
# hidden_layers=2 hidden_units_per_layer=128 optimizer='SGD'
# training elapsed_time =      181.4
# Test accuracy: 0.9739999771118164
# 60000 train samples
# 10000 test samples
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dense_layer_3 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 189,706
# Trainable params: 189,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 86: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0906 - accuracy: 0.9727
# hidden_layers=2 hidden_units_per_layer=192 optimizer='SGD'
# training elapsed_time =      120.0
# Test accuracy: 0.9726999998092651
# 60000 train samples
# 10000 test samples
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dense_layer_3 (Dense)       (None, 64)                4160
#
#  dense_layer_4 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 71: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9692
# hidden_layers=3 hidden_units_per_layer=64 optimizer='SGD'
# training elapsed_time =      112.8
# Test accuracy: 0.9692000150680542
# 60000 train samples
# 10000 test samples
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dense_layer_3 (Dense)       (None, 128)               16512
#
#  dense_layer_4 (Dense)       (None, 10)                1290
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 72: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0851 - accuracy: 0.9732
# hidden_layers=3 hidden_units_per_layer=128 optimizer='SGD'
# training elapsed_time =      117.5
# Test accuracy: 0.9732000231742859
# 60000 train samples
# 10000 test samples
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dense_layer_3 (Dense)       (None, 192)               37056
#
#  dense_layer_4 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 226,762
# Trainable params: 226,762
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 69: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0858 - accuracy: 0.9731
# hidden_layers=3 hidden_units_per_layer=192 optimizer='SGD'
# training elapsed_time =      103.2
# Test accuracy: 0.9731000065803528
# 60000 train samples
# 10000 test samples
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dense_layer_3 (Dense)       (None, 64)                4160
#
#  dense_layer_4 (Dense)       (None, 64)                4160
#
#  dense_layer_5 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 63,370
# Trainable params: 63,370
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 47: early stopping
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1125 - accuracy: 0.9658
# hidden_layers=4 hidden_units_per_layer=64 optimizer='SGD'
# training elapsed_time =       79.0
# Test accuracy: 0.9657999873161316
# 60000 train samples
# 10000 test samples
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dense_layer_3 (Dense)       (None, 128)               16512
#
#  dense_layer_4 (Dense)       (None, 128)               16512
#
#  dense_layer_5 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 42: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1076 - accuracy: 0.9670
# hidden_layers=4 hidden_units_per_layer=128 optimizer='SGD'
# training elapsed_time =       72.4
# Test accuracy: 0.9670000076293945
# 60000 train samples
# 10000 test samples
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dense_layer_3 (Dense)       (None, 192)               37056
#
#  dense_layer_4 (Dense)       (None, 192)               37056
#
#  dense_layer_5 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 263,818
# Trainable params: 263,818
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 53: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0878 - accuracy: 0.9741
# hidden_layers=4 hidden_units_per_layer=192 optimizer='SGD'
# training elapsed_time =       85.7
# Test accuracy: 0.9740999937057495
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0               1                      64    226.860444         0.9695
# 1               1                     128    284.873076         0.9740
# 2               1                     192    311.766825         0.9762
# 3               2                      64    169.503165         0.9706
# 4               2                     128    181.412843         0.9740
# 5               2                     192    119.954419         0.9727
# 6               3                      64    112.754358         0.9692
# 7               3                     128    117.475517         0.9732
# 8               3                     192    103.170377         0.9731
# 9               4                      64     79.026243         0.9658
# 10              4                     128     72.401877         0.9670
# 11              4                     192     85.724269         0.9741
# Saving results to file data/DENSE_SGD_2022-09-30_23_09.csv

# %%
import pandas as pd
df = pd.read_csv('data/DENSE_SGD_2022-09-30_23_09.csv')
display(df)
df[['elapsed_time','test_accuracy']].describe()
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0               1                      64    226.860444         0.9695
# 1               1                     128    284.873076         0.9740
# 2               1                     192    311.766825         0.9762
# 3               2                      64    169.503165         0.9706
# 4               2                     128    181.412843         0.9740
# 5               2                     192    119.954419         0.9727
# 6               3                      64    112.754358         0.9692
# 7               3                     128    117.475517         0.9732
# 8               3                     192    103.170377         0.9731
# 9               4                      64     79.026243         0.9658
# 10              4                     128     72.401877         0.9670
# 11              4                     192     85.724269         0.9741
#        elapsed_time  test_accuracy
# count     12.000000      12.000000
# mean     155.410284       0.971617
# std       80.911629       0.003175
# min       72.401877       0.965800
# 25%       98.808850       0.969425
# 50%      118.714968       0.972900
# 75%      192.774743       0.974000
# max      311.766825       0.976200
