# %% [markdown]
# ## Deeper Dense Models (Adam optimizer with Dropout)

# %%
import pandas as pd
import numpy as np

# %%
# %run load_mnist_dataset_flat.py

# %%
## Script create_dense_model.py
import tensorflow as tf
import numpy as np
from tensorflow import keras
DIGIT_CLASSES = 10
RESHAPED = 28 * 28 ## 784 pixels per image
import time
from datetime import datetime


def create_dense_model(hidden_layers=1, hidden_units_per_layer=128):
    """
    create a keras sequential model with the specified
    number of hidden_layers and number of units per layer
    """
    DIGIT_CLASSES = 10
    RESHAPED = 28 * 28 ## 784 pixels per image
    DROPOUT = 0.3
    model = tf.keras.models.Sequential()
    count = 0
    
    
    count += 1
    model.add(keras.layers.Dense(units=hidden_units_per_layer,
        input_shape=(RESHAPED,),
        name=f'dense_layer_{count}', activation='relu'))
    
    for i in range(1, hidden_layers):
        count += 1
        model.add(keras.layers.Dense(units=hidden_units_per_layer,
           name=f'dense_layer_{count}', activation='relu'))
        ## Droput added after each hidden layer to help with regularization
        model.add(keras.layers.Dropout(DROPOUT))
        
    count += 1        
    model.add(keras.layers.Dense(DIGIT_CLASSES,
       name=f'dense_layer_{count}', activation='softmax'))

    # summary of the model
    model.summary()
    return model


def run_dense_model(hidden_layers=1, hidden_units_per_layer=128, optimizer='SGD', verbose=1):
    """
    Create and run a dense Keras sequential model over the MNIST training data,
    using the specified numbers of hidden_layers, hidden_units_per_layer, and optimizer.
    Maybe add optional dropout TBD,
    Return values:
    history, training_time, test_accuracy, model
    """
    from keras.callbacks import EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss',verbose=1,patience=3,min_delta=0.0001)
    
    BATCH_SIZE = 128
    EPOCHS = 400
    VALIDATION_SPLIT = 0.2
    
    ## Load the training and test data
    X_train, X_test, Y_train, Y_test = load_mnist_dataset_flat()
    
    model = create_dense_model(hidden_layers, hidden_units_per_layer)
    
    start_time = time.time()

    # compiling the model
    model.compile(optimizer=optimizer, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    #training the model
    history = model.fit(X_train, Y_train,
                        batch_size=BATCH_SIZE, epochs=EPOCHS,
                        verbose=verbose, validation_split=VALIDATION_SPLIT,
                        callbacks=[early_stopping]
                       )
    
    elapsed_time = time.time() - start_time
    
    test_loss, test_accuracy = model.evaluate(X_test, Y_test)
    print(f'{hidden_layers=} {hidden_units_per_layer=} {optimizer=}')
    print(f'training elapsed_time = {elapsed_time:10.1f}')
    print('Test accuracy:', test_accuracy)
    
    return history, elapsed_time, test_accuracy, model

# %%
model = create_dense_model(hidden_layers=1, hidden_units_per_layer=64)
model.summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x0000018A0AC16D00>>

# %%
dense1 = pd.read_csv('data/dense_network_comparisons.csv')
display(dense1)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0    256.643188         0.9716
# 1             1.0                   128.0    269.815770         0.9742
# 2             1.0                   192.0    265.792969         0.9763
# 3             2.0                    64.0    134.144796         0.9690
# 4             2.0                   128.0    148.220814         0.9734
# 5             2.0                   192.0    147.220577         0.9746
# 6             3.0                    64.0     94.210800         0.9673
# 7             3.0                   128.0    106.395729         0.9729
# 8             3.0                   192.0     87.828249         0.9749
# 9             4.0                    64.0     69.781558         0.9695
# 10            4.0                   128.0     90.105224         0.9722
# 11            4.0                   192.0     99.254324         0.9722

# %%
dense2 = pd.read_csv('data/dense_network_comparisons2.csv')
display(dense2)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0     21.059321         0.9735
# 1             1.0                   128.0     19.197610         0.9765
# 2             1.0                   192.0     17.795359         0.9792
# 3             2.0                    64.0     15.609005         0.9716
# 4             2.0                   128.0     13.113215         0.9759
# 5             2.0                   192.0     13.247705         0.9776
# 6             3.0                    64.0     15.438182         0.9726
# 7             3.0                   128.0     13.106203         0.9698
# 8             3.0                   192.0     14.660831         0.9793
# 9             4.0                    64.0     20.492837         0.9721
# 10            4.0                   128.0     15.320420         0.9721
# 11            4.0                   192.0     12.650368         0.9774

# %%
dropout1 = pd.read_csv('data/dense_network_comparisons.csv')
display(dropout1)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0    256.643188         0.9716
# 1             1.0                   128.0    269.815770         0.9742
# 2             1.0                   192.0    265.792969         0.9763
# 3             2.0                    64.0    134.144796         0.9690
# 4             2.0                   128.0    148.220814         0.9734
# 5             2.0                   192.0    147.220577         0.9746
# 6             3.0                    64.0     94.210800         0.9673
# 7             3.0                   128.0    106.395729         0.9729
# 8             3.0                   192.0     87.828249         0.9749
# 9             4.0                    64.0     69.781558         0.9695
# 10            4.0                   128.0     90.105224         0.9722
# 11            4.0                   192.0     99.254324         0.9722

# %%
dropout2 = pd.read_csv('data/dense_network_comparisons2.csv')
display(dropout2)
# Out:
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0             1.0                    64.0     21.059321         0.9735
# 1             1.0                   128.0     19.197610         0.9765
# 2             1.0                   192.0     17.795359         0.9792
# 3             2.0                    64.0     15.609005         0.9716
# 4             2.0                   128.0     13.113215         0.9759
# 5             2.0                   192.0     13.247705         0.9776
# 6             3.0                    64.0     15.438182         0.9726
# 7             3.0                   128.0     13.106203         0.9698
# 8             3.0                   192.0     14.660831         0.9793
# 9             4.0                    64.0     20.492837         0.9721
# 10            4.0                   128.0     15.320420         0.9721
# 11            4.0                   192.0     12.650368         0.9774

# %%
LABEL = 'Adam_Dropout'
OPTIMIZER = 'Adam'
units = [64,128,192]
hidden_layers = [1,2,3,4]

test_data2 = []

for layers in hidden_layers:
    for hidden_units in units:
        history, elapsed_time, test_accuracy, model = \
        run_dense_model(hidden_layers=layers, hidden_units_per_layer=hidden_units, verbose=0, optimizer=OPTIMIZER)
        
        data2 = (layers, hidden_units, elapsed_time, test_accuracy)
        
        test_data2.append(data2)
        
        
df = pd.DataFrame(test_data2)
df.columns = ['hidden_layers', 'hidden_units_per_layer', 'elapsed_time', 'test_accuracy']
display(df)
path = f'data/DENSE_{LABEL}'
now = datetime.now()
result_name = now.strftime(f"{path}_%Y-%m-%d_%H_%M.csv")
print(f'Saving results to file {result_name}')
df.to_csv(result_name, index=False)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 23: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0962 - accuracy: 0.9728
# hidden_layers=1 hidden_units_per_layer=64 optimizer='Adam'
# training elapsed_time =       30.9
# Test accuracy: 0.9728000164031982
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 16: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0749 - accuracy: 0.9780
# hidden_layers=1 hidden_units_per_layer=128 optimizer='Adam'
# training elapsed_time =       22.2
# Test accuracy: 0.9779999852180481
# 60000 train samples
# 10000 test samples
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 152,650
# Trainable params: 152,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 12: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0700 - accuracy: 0.9790
# hidden_layers=1 hidden_units_per_layer=192 optimizer='Adam'
# training elapsed_time =       16.2
# Test accuracy: 0.9789999723434448
# 60000 train samples
# 10000 test samples
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_layer_3 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 16: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0857 - accuracy: 0.9766
# hidden_layers=2 hidden_units_per_layer=64 optimizer='Adam'
# training elapsed_time =       26.2
# Test accuracy: 0.9765999913215637
# 60000 train samples
# 10000 test samples
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 14: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0823 - accuracy: 0.9790
# hidden_layers=2 hidden_units_per_layer=128 optimizer='Adam'
# training elapsed_time =       21.9
# Test accuracy: 0.9789999723434448
# 60000 train samples
# 10000 test samples
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dropout_2 (Dropout)         (None, 192)               0
#
#  dense_layer_3 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 189,706
# Trainable params: 189,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 10: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0807 - accuracy: 0.9792
# hidden_layers=2 hidden_units_per_layer=192 optimizer='Adam'
# training elapsed_time =       16.1
# Test accuracy: 0.979200005531311
# 60000 train samples
# 10000 test samples
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_layer_3 (Dense)       (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_layer_4 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 14: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0973 - accuracy: 0.9734
# hidden_layers=3 hidden_units_per_layer=64 optimizer='Adam'
# training elapsed_time =       27.4
# Test accuracy: 0.9733999967575073
# 60000 train samples
# 10000 test samples
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 128)               16512
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_layer_4 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 11: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0858 - accuracy: 0.9774
# hidden_layers=3 hidden_units_per_layer=128 optimizer='Adam'
# training elapsed_time =       19.8
# Test accuracy: 0.977400004863739
# 60000 train samples
# 10000 test samples
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dropout_7 (Dropout)         (None, 192)               0
#
#  dense_layer_3 (Dense)       (None, 192)               37056
#
#  dropout_8 (Dropout)         (None, 192)               0
#
#  dense_layer_4 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 226,762
# Trainable params: 226,762
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 8: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0829 - accuracy: 0.9765
# hidden_layers=3 hidden_units_per_layer=192 optimizer='Adam'
# training elapsed_time =       15.0
# Test accuracy: 0.9764999747276306
# 60000 train samples
# 10000 test samples
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 64)                50240
#
#  dense_layer_2 (Dense)       (None, 64)                4160
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_layer_3 (Dense)       (None, 64)                4160
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_layer_4 (Dense)       (None, 64)                4160
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_layer_5 (Dense)       (None, 10)                650
#
# =================================================================
# Total params: 63,370
# Trainable params: 63,370
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 17: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1241 - accuracy: 0.9723
# hidden_layers=4 hidden_units_per_layer=64 optimizer='Adam'
# training elapsed_time =       35.2
# Test accuracy: 0.9722999930381775
# 60000 train samples
# 10000 test samples
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 128)               100480
#
#  dense_layer_2 (Dense)       (None, 128)               16512
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_layer_3 (Dense)       (None, 128)               16512
#
#  dropout_13 (Dropout)        (None, 128)               0
#
#  dense_layer_4 (Dense)       (None, 128)               16512
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_layer_5 (Dense)       (None, 10)                1290
#
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 11: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0989 - accuracy: 0.9769
# hidden_layers=4 hidden_units_per_layer=128 optimizer='Adam'
# training elapsed_time =       22.6
# Test accuracy: 0.9768999814987183
# 60000 train samples
# 10000 test samples
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_layer_1 (Dense)       (None, 192)               150720
#
#  dense_layer_2 (Dense)       (None, 192)               37056
#
#  dropout_15 (Dropout)        (None, 192)               0
#
#  dense_layer_3 (Dense)       (None, 192)               37056
#
#  dropout_16 (Dropout)        (None, 192)               0
#
#  dense_layer_4 (Dense)       (None, 192)               37056
#
#  dropout_17 (Dropout)        (None, 192)               0
#
#  dense_layer_5 (Dense)       (None, 10)                1930
#
# =================================================================
# Total params: 263,818
# Trainable params: 263,818
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 13: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0980 - accuracy: 0.9785
# hidden_layers=4 hidden_units_per_layer=192 optimizer='Adam'
# training elapsed_time =       26.5
# Test accuracy: 0.9785000085830688
#     hidden_layers  hidden_units_per_layer  elapsed_time  test_accuracy
# 0               1                      64     30.902522         0.9728
# 1               1                     128     22.212532         0.9780
# 2               1                     192     16.219516         0.9790
# 3               2                      64     26.160845         0.9766
# 4               2                     128     21.860066         0.9790
# 5               2                     192     16.069946         0.9792
# 6               3                      64     27.400348         0.9734
# 7               3                     128     19.842423         0.9774
# 8               3                     192     15.032671         0.9765
# 9               4                      64     35.237027         0.9723
# 10              4                     128     22.631395         0.9769
# 11              4                     192     26.536014         0.9785
# Saving results to file data/DENSE_Adam_Dropout_2022-09-30_22_34.csv
